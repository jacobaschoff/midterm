# %%
import pygam as pygam
import pandas as pd
import patsy as pt
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tsa.arima import model
from pygam import LinearGAM, s, f, l

# %%
# Reading in and cleaning data

# Office of Field Operations data 2019 - 2023
OFOTwentyThree = pd.read_csv("https://raw.githubusercontent.com/jacobaschoff/midterm/main/nationwide-drugs-fy20-fy23%20(3).csv")
nineteen = pd.read_csv("https://raw.githubusercontent.com/jacobaschoff/midterm/main/nationwide-drugs-fy19-fy22.csv")
OFOTwnetyNineteen = nineteen[nineteen['FY']==2019]

# Air and Marine Operations data 2019 - 2023
#AMOTwentyThree = pd.read_csv("https://raw.githubusercontent.com/jacobaschoff/midterm/main/amo-drug-seizures-fy20-fy23.csv")
#AMOnineteen = pd.read_csv("https://raw.githubusercontent.com/jacobaschoff/midterm/main/amo-drug-seizures-fy19-fy22.csv")
#AMOTwentyNineteen = AMOnineteen[AMOnineteen['FY']==2019]

# Combining data and transferring to 

data = pd.concat([OFOTwnetyNineteen, OFOTwentyThree])

# Identifying cities for mapping the data

city_pattern = r'(.+)(?: FIELD OFFICE| SECTOR)'
data['City'] = data['Area of Responsibility'].str.extract(city_pattern)

# Matching cities with states

citiesandstates = pd.read_csv('https://raw.githubusercontent.com/jacobaschoff/midterm/main/uscities.csv')
citiesandstates = citiesandstates.rename(columns={'city_ascii' : 'City'})
citiesandstates = citiesandstates.rename(columns={'state_name' : 'State'})
citiesandstates['City'] = citiesandstates['City'].str.upper()

data = pd.merge(data, citiesandstates[['City', 'State']], on='City', how='left')
data
# Out:
#          FY Month (abbv)                   Component            Region  \
# 0      2019          APR  Office of Field Operations  Coastal/Interior
# 1      2019          APR  Office of Field Operations  Coastal/Interior
# 2      2019          APR  Office of Field Operations  Coastal/Interior
# 3      2019          APR  Office of Field Operations  Coastal/Interior
# 4      2019          APR  Office of Field Operations  Coastal/Interior
# ...     ...          ...                         ...               ...
# 42185  2023          SEP          U.S. Border Patrol  Southwest Border
# 42186  2023          SEP          U.S. Border Patrol  Southwest Border
# 42187  2023          SEP          U.S. Border Patrol  Southwest Border
# 42188  2023          SEP          U.S. Border Patrol  Southwest Border
# 42189  2023          SEP          U.S. Border Patrol  Southwest Border
#
#       Land Filter Area of Responsibility        Drug Type  Count of Event  \
# 0           Other   ATLANTA FIELD OFFICE          Ecstasy               3
# 1           Other   ATLANTA FIELD OFFICE          Ecstasy               3
# 2           Other   ATLANTA FIELD OFFICE          Ecstasy               3
# 3           Other   ATLANTA FIELD OFFICE          Ecstasy               3
# 4           Other   ATLANTA FIELD OFFICE          Ecstasy               3
# ...           ...                    ...              ...             ...
# 42185   Land Only            YUMA SECTOR  Methamphetamine               2
# 42186   Land Only            YUMA SECTOR  Methamphetamine               2
# 42187   Land Only            YUMA SECTOR    Other Drugs**               2
# 42188   Land Only            YUMA SECTOR    Other Drugs**               2
# 42189   Land Only            YUMA SECTOR    Other Drugs**               2
#
#        Sum Qty (lbs)     City      State
# 0           8.379947  ATLANTA    Georgia
# 1           8.379947  ATLANTA      Texas
# 2           8.379947  ATLANTA   Illinois
# 3           8.379947  ATLANTA    Indiana
# 4           8.379947  ATLANTA   Michigan
# ...              ...      ...        ...
# 42185      84.452600     YUMA   Colorado
# 42186      84.452600     YUMA  Tennessee
# 42187       1.748300     YUMA    Arizona
# 42188       1.748300     YUMA   Colorado
# 42189       1.748300     YUMA  Tennessee
#
# [42190 rows x 11 columns]

# %%
data = data.rename(columns={'Sum Qty (lbs)': 'Qty', 'Drug Type': 'Drug', 'Area of Responsibility': 'Office', 'Count of Event': 'Count'})
data.head()
# Out:
#      FY Month (abbv)                   Component            Region  \
# 0  2019          APR  Office of Field Operations  Coastal/Interior
# 1  2019          APR  Office of Field Operations  Coastal/Interior
# 2  2019          APR  Office of Field Operations  Coastal/Interior
# 3  2019          APR  Office of Field Operations  Coastal/Interior
# 4  2019          APR  Office of Field Operations  Coastal/Interior
#
#   Land Filter                Office     Drug  Count       Qty     City  \
# 0       Other  ATLANTA FIELD OFFICE  Ecstasy      3  8.379947  ATLANTA
# 1       Other  ATLANTA FIELD OFFICE  Ecstasy      3  8.379947  ATLANTA
# 2       Other  ATLANTA FIELD OFFICE  Ecstasy      3  8.379947  ATLANTA
# 3       Other  ATLANTA FIELD OFFICE  Ecstasy      3  8.379947  ATLANTA
# 4       Other  ATLANTA FIELD OFFICE  Ecstasy      3  8.379947  ATLANTA
#
#       State
# 0   Georgia
# 1     Texas
# 2  Illinois
# 3   Indiana
# 4  Michigan

# %%
data.dtypes

# %%
data['OfficeNum'] = pd.factorize(data['Office'])[0]
data['DrugNum'] = pd.factorize(data['Drug'])[0]
data.head(100)
# Out:
#       FY Month (abbv)                   Component            Region  \
# 0   2019          APR  Office of Field Operations  Coastal/Interior
# 1   2019          APR  Office of Field Operations  Coastal/Interior
# 2   2019          APR  Office of Field Operations  Coastal/Interior
# 3   2019          APR  Office of Field Operations  Coastal/Interior
# 4   2019          APR  Office of Field Operations  Coastal/Interior
# ..   ...          ...                         ...               ...
# 95  2019          APR  Office of Field Operations  Coastal/Interior
# 96  2019          APR  Office of Field Operations  Coastal/Interior
# 97  2019          APR  Office of Field Operations  Coastal/Interior
# 98  2019          APR  Office of Field Operations  Coastal/Interior
# 99  2019          APR  Office of Field Operations  Coastal/Interior
#
#    Land Filter                    Office      Drug  Count        Qty  \
# 0        Other      ATLANTA FIELD OFFICE   Ecstasy      3   8.379947
# 1        Other      ATLANTA FIELD OFFICE   Ecstasy      3   8.379947
# 2        Other      ATLANTA FIELD OFFICE   Ecstasy      3   8.379947
# 3        Other      ATLANTA FIELD OFFICE   Ecstasy      3   8.379947
# 4        Other      ATLANTA FIELD OFFICE   Ecstasy      3   8.379947
# ..         ...                       ...       ...    ...        ...
# 95       Other  LOS ANGELES FIELD OFFICE   Cocaine     24  90.790703
# 96       Other  LOS ANGELES FIELD OFFICE   Cocaine     24  90.790703
# 97       Other  LOS ANGELES FIELD OFFICE   Ecstasy     20   2.787084
# 98       Other  LOS ANGELES FIELD OFFICE   Ecstasy     20   2.787084
# 99       Other  LOS ANGELES FIELD OFFICE  Fentanyl      3   0.509709
#
#            City       State  OfficeNum  DrugNum
# 0       ATLANTA     Georgia          0        0
# 1       ATLANTA       Texas          0        0
# 2       ATLANTA    Illinois          0        0
# 3       ATLANTA     Indiana          0        0
# 4       ATLANTA    Michigan          0        0
# ..          ...         ...        ...      ...
# 95  LOS ANGELES  California          4        4
# 96  LOS ANGELES       Texas          4        4
# 97  LOS ANGELES  California          4        0
# 98  LOS ANGELES       Texas          4        0
# 99  LOS ANGELES  California          4        5
#
# [100 rows x 13 columns]

# %%
data.dtypes
# Out:
# FY                int64
# Month (abbv)     object
# Component        object
# Region           object
# Land Filter      object
# Office           object
# Drug             object
# Count             int64
# Qty             float64
# City             object
# State            object
# OfficeNum         int64
# DrugNum           int64
# dtype: object

# %%
data.Drug.unique()
#data.DrugNum.unique()
# Out:
# array(['ATLANTA FIELD OFFICE', 'BALTIMORE FIELD OFFICE',
#        'CHICAGO FIELD OFFICE', 'HOUSTON FIELD OFFICE',
#        'LOS ANGELES FIELD OFFICE', 'MIAMI FIELD OFFICE',
#        'NEW ORLEANS FIELD OFFICE', 'NEW YORK FIELD OFFICE',
#        'PRECLEARANCE FIELD OFFICE', 'SAN FRANCISCO FIELD OFFICE',
#        'SAN JUAN FIELD OFFICE', 'TAMPA FIELD OFFICE',
#        'BOSTON FIELD OFFICE', 'BUFFALO FIELD OFFICE',
#        'DETROIT FIELD OFFICE', 'SEATTLE FIELD OFFICE',
#        'PORTLAND FIELD OFFICE', 'EL PASO FIELD OFFICE',
#        'LAREDO FIELD OFFICE', 'SAN DIEGO FIELD OFFICE',
#        'TUCSON FIELD OFFICE', 'MIAMI SECTOR', 'BLAINE SECTOR',
#        'BUFFALO SECTOR', 'DETROIT SECTOR', 'HAVRE SECTOR',
#        'HOULTON SECTOR', 'SPOKANE SECTOR', 'SWANTON SECTOR',
#        'BIG BEND SECTOR', 'DEL RIO SECTOR', 'EL CENTRO SECTOR',
#        'EL PASO SECTOR', 'LAREDO SECTOR', 'RIO GRANDE VALLEY SECTOR',
#        'SAN DIEGO SECTOR', 'TUCSON SECTOR', 'YUMA SECTOR',
#        'NEW ORLEANS SECTOR', 'RAMEY SECTOR', 'GRAND FORKS SECTOR'],
#       dtype=object)

# %%
regression = smf.ols("OfficeNum ~ -1  + FY +  Count + Qty + DrugNum", data=data)

# %%
xgam = data[['FY','Count','Qty','DrugNum']]
ygam = data[['OfficeNum']]

# %%
model = """OfficeNum ~ -1  + FY +  Count + Qty + DrugNum"""
y,x = pt.dmatrices(model, data=data)

# %%
model = LinearGAM(s(0) + s(1) + s(2) + s(3))
modelFit = model.gridsearch(np.asarray(x), y)
# Out:
# 100% (11 of 11) |########################| Elapsed Time: 0:00:12 Time:  0:00:120:01

# %%
# Import plotly tools to create a grid of subplots (figures) that work together
from plotly import tools
import plotly.offline as py
import plotly.graph_objs as go

# Name each figure
titles = ['year', 'Count', 'Qty', 'Drug']

# Create the subplots in a single-row grid
fig = tools.make_subplots(rows=1, cols=4, subplot_titles=titles)
# Dictate the size of the figure, title, etc.
fig['layout'].update(height=500, width=1000, title='pyGAM', showlegend=False)

# Loop over the titles, and create the corresponding figures
for i, title in enumerate(titles):
    # Create the grid over which to estimate the effect of parameters
    XX = modelFit.generate_X_grid(term=i)
    # Calculate the value and 95% confidence intervals for each parameter
    # This will become the expected effect on the dependent variable for a given value of x
    pdep, confi = modelFit.partial_dependence(term=i, width=.95)
    
    # Create the effect and confidence interval traces (there are 3 total)
    trace = go.Scatter(x=XX[:,i], y=pdep, mode='lines', name='Effect')
    ci1 = go.Scatter(x = XX[:,i], y=confi[:,0], line=dict(dash='dash', color='grey'), name='95% CI')
    ci2 = go.Scatter(x = XX[:,i], y=confi[:,1], line=dict(dash='dash', color='grey'), name='95% CI')

    # Add each of the three traces to the figure in the relevant grid position
    fig.append_trace(trace, 1, i+1)
    fig.append_trace(ci1, 1, i+1)
    fig.append_trace(ci2, 1, i+1)

#Plot the figure
py.iplot(fig)
# Out:
# C:\Users\ryanh\anaconda3\Lib\site-packages\plotly\tools.py:460: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
# <div>                            <div id="cba17f44-b52d-4aa1-8875-931468b4fa13" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cba17f44-b52d-4aa1-8875-931468b4fa13")) {                    Plotly.newPlot(                        "cba17f44-b52d-4aa1-8875-931468b4fa13",                        [{"mode":"lines","name":"Effect","x":[2019.0,2019.040404040404,2019.080808080808,2019.121212121212,2019.1616161616162,2019.20202020202,2019.2424242424242,2019.2828282828282,2019.3232323232323,2019.3636363636363,2019.4040404040404,2019.4444444444443,2019.4848484848485,2019.5252525252524,2019.5656565656566,2019.6060606060605,2019.6464646464647,2019.6868686868686,2019.7272727272727,2019.7676767676767,2019.8080808080808,2019.8484848484848,2019.888888888889,2019.9292929292928,2019.969696969697,2020.010101010101,2020.050505050505,2020.090909090909,2020.1313131313132,2020.171717171717,2020.2121212121212,2020.2525252525252,2020.2929292929293,2020.3333333333333,2020.3737373737374,2020.4141414141413,2020.4545454545455,2020.4949494949494,2020.5353535353536,2020.5757575757575,2020.6161616161617,2020.6565656565656,2020.6969696969697,2020.7373737373737,2020.7777777777778,2020.8181818181818,2020.858585858586,2020.8989898989898,2020.939393939394,2020.979797979798,2021.020202020202,2021.060606060606,2021.1010101010102,2021.141414141414,2021.1818181818182,2021.2222222222222,2021.2626262626263,2021.3030303030303,2021.3434343434344,2021.3838383838383,2021.4242424242425,2021.4646464646464,2021.5050505050506,2021.5454545454545,2021.5858585858587,2021.6262626262626,2021.6666666666667,2021.7070707070707,2021.7474747474748,2021.7878787878788,2021.828282828283,2021.8686868686868,2021.909090909091,2021.949494949495,2021.989898989899,2022.030303030303,2022.0707070707072,2022.111111111111,2022.1515151515152,2022.1919191919192,2022.2323232323233,2022.2727272727273,2022.3131313131314,2022.3535353535353,2022.3939393939395,2022.4343434343434,2022.4747474747476,2022.5151515151515,2022.5555555555557,2022.5959595959596,2022.6363636363637,2022.6767676767677,2022.7171717171718,2022.7575757575758,2022.79797979798,2022.8383838383838,2022.878787878788,2022.919191919192,2022.959595959596,2023.0],"xaxis":"x","y":[-0.008416545472123775,0.008217396168394798,0.02470577571366106,0.04098134953637341,0.05697687400959848,0.07262510550604023,0.08785878808044766,0.10260706519066527,0.11679049625733885,0.130328388795448,0.14314005032028368,0.15514478834684076,0.16626191038892324,0.17641072388316073,0.18551053615327195,0.1934806545137024,0.200240386279089,0.20570903876390353,0.20980622246482478,0.2124576447908316,0.21359465965710067,0.21314883391322442,0.21105173440880254,0.20723492799346377,0.20163623658296628,0.19425674586164204,0.18513427554826073,0.17430709784052406,0.16181348493590963,0.14769170903215723,0.13198633273801666,0.11477783085371596,0.09615940251630115,0.07622426177382541,0.0550656226739086,0.0327766992800344,0.009450795417740685,-0.014818483932667784,-0.03993747070504959,-0.06581249683270815,-0.09234989424952,-0.11945599641871128,-0.1470373520712521,-0.17500094530064847,-0.20325381272095422,-0.2317029909455911,-0.2602555165886184,-0.28881861488369615,-0.3173063585848044,-0.3456414447346414,-0.3737471202897854,-0.4015466322061799,-0.4289632274403972,-0.45592070285491243,-0.4823514794968245,-0.5081948258486658,-0.5333901990114948,-0.5578770560857952,-0.5815948541726101,-0.6044831028494393,-0.6264817467016391,-0.6475309454052657,-0.6675708601655477,-0.6865416521872517,-0.7043834826755826,-0.7210365607192616,-0.7364413239900323,-0.7505382782910016,-0.763267929437299,-0.7745707832437523,-0.7843873568694845,-0.7926678481814828,-0.7993897771333137,-0.8045354494392996,-0.8080871708138968,-0.8100272469714633,-0.8103383278767193,-0.8090310111106275,-0 ...
