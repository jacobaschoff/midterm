# %%
# Import pandas and others

import pandas as pd
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing
import numpy as np
import plotly.express as px
import patsy as pt
import numpy as np
from plotly import tools
import plotly.offline as py
import plotly.graph_objs as go

# Load data from the CSV
data = pd.read_csv("https://raw.githubusercontent.com/jacobaschoff/midterm/main/Fentanyl%20All%20Countries.csv")

# %%
# Data from .csv file
data
# Out:
#      Country or Area  Year                                          Commodity  \
# 0            Albania  2007  Heterocyclic compounds; containing an unfused ...
# 1            Algeria  2017  Heterocyclic compounds; containing an unfused ...
# 2            Algeria  2016  Heterocyclic compounds; containing an unfused ...
# 3            Algeria  2015  Heterocyclic compounds; containing an unfused ...
# 4            Algeria  2014  Heterocyclic compounds; containing an unfused ...
# ...              ...   ...                                                ...
# 2609        Zimbabwe  2010  Heterocyclic compounds; containing an unfused ...
# 2610        Zimbabwe  2008  Heterocyclic compounds; containing an unfused ...
# 2611        Zimbabwe  2007  Heterocyclic compounds; containing an unfused ...
# 2612        Zimbabwe  2005  Heterocyclic compounds; containing an unfused ...
# 2613        Zimbabwe  2004  Heterocyclic compounds; containing an unfused ...
#
# ...

# %%
# Put data into pandas dataframe
data = pd.DataFrame(data)

# %%
# Pandas dataframe
data
# Out:
#      Country or Area  Year                                          Commodity  \
# 0            Albania  2007  Heterocyclic compounds; containing an unfused ...
# 1            Algeria  2017  Heterocyclic compounds; containing an unfused ...
# 2            Algeria  2016  Heterocyclic compounds; containing an unfused ...
# 3            Algeria  2015  Heterocyclic compounds; containing an unfused ...
# 4            Algeria  2014  Heterocyclic compounds; containing an unfused ...
# ...              ...   ...                                                ...
# 2609        Zimbabwe  2010  Heterocyclic compounds; containing an unfused ...
# 2610        Zimbabwe  2008  Heterocyclic compounds; containing an unfused ...
# 2611        Zimbabwe  2007  Heterocyclic compounds; containing an unfused ...
# 2612        Zimbabwe  2005  Heterocyclic compounds; containing an unfused ...
# 2613        Zimbabwe  2004  Heterocyclic compounds; containing an unfused ...
#
# ...

# %%
# Split data frame in imports and exports for China, Mexico, and India
chinaExportData = data[(data['Country or Area'] == 'China') & (data['Flow'] == 'Export')]
chinaImportData = data[(data['Country or Area'] == 'China') & (data['Flow'] == 'Import')]
mexicoExportData = data[(data['Country or Area'] == 'Mexico') & (data['Flow'] == 'Export')]
mexicoImportData = data[(data['Country or Area'] == 'Mexico') & (data['Flow'] == 'Import')]
indiaExportData = data[(data['Country or Area'] == 'India') & (data['Flow'] == 'Export')]
indiaImportData = data[(data['Country or Area'] == 'India') & (data['Flow'] == 'Import')]

# %%
# Create plots for imports and exports of China, Mexico, and India
figChinaEx = px.line(chinaExportData, x='Year', y='Weight (kg)')
figChinaImp = px.line(chinaImportData, x='Year', y='Weight (kg)')
figMexicoEx = px.line(mexicoExportData, x='Year', y='Weight (kg)')
figMexicoImp = px.line(mexicoImportData, x='Year', y='Weight (kg)')
figIndiaEx = px.line(indiaExportData, x='Year', y='Weight (kg)')
figIndiaImp = px.line(indiaImportData, x='Year', y='Weight (kg)')

# %%
figChinaEx
# Out:
# <div>                            <div id="f793a04c-b812-42ff-acef-d1d783eec98c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f793a04c-b812-42ff-acef-d1d783eec98c")) {                    Plotly.newPlot(                        "f793a04c-b812-42ff-acef-d1d783eec98c",                        [{"hovertemplate":"Year=%{x}<br>Weight (kg)=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2022,2022,2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002],"xaxis":"x","y":[13.966,23.0,18.104,16.849,6.857,3.289,2.011,null,251.024,4.0,508.0,3.0,null,204.0,310.0,1248.0,699.0,1426.0,13535.0,3114
# ...

# %%
figChinaImp
# Out:
# <div>                            <div id="23b98bad-1094-4e26-a1a1-a9fc28633199" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23b98bad-1094-4e26-a1a1-a9fc28633199")) {                    Plotly.newPlot(                        "23b98bad-1094-4e26-a1a1-a9fc28633199",                        [{"hovertemplate":"Year=%{x}<br>Weight (kg)=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2022,2022,2022,2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002],"xaxis":"x","y":[null,null,null,null,null,null,null,14.602,null,null,null,null,null,null,null,null,141.0,62.0,206.0,77.0,1763.0,null
# ...

# %%
figMexicoEx
# Out:
# <div>                            <div id="1c4eb3e2-c810-4d0a-ba55-e2bed0273d02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c4eb3e2-c810-4d0a-ba55-e2bed0273d02")) {                    Plotly.newPlot(                        "1c4eb3e2-c810-4d0a-ba55-e2bed0273d02",                        [{"hovertemplate":"Year=%{x}<br>Weight (kg)=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2007,2006],"xaxis":"x","y":[null,null],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111
# ...

# %%
figMexicoImp
# Out:
# <div>                            <div id="9b6c78b7-11f0-4b72-9026-053f70c9be13" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b6c78b7-11f0-4b72-9026-053f70c9be13")) {                    Plotly.newPlot(                        "9b6c78b7-11f0-4b72-9026-053f70c9be13",                        [{"hovertemplate":"Year=%{x}<br>Weight (kg)=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002],"xaxis":"x","y":[null,null,null,null,null,null,null,637.0,611.0,666.0,353.0,217.0,295.0,139.0,308.0,325.0,316.0,224.0,3397.0],"yaxis":"y","type":"scatte
# ...

# %%
figIndiaEx
# Out:
# <div>                            <div id="a396aa44-4a3f-4c7e-8004-838628386109" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a396aa44-4a3f-4c7e-8004-838628386109")) {                    Plotly.newPlot(                        "a396aa44-4a3f-4c7e-8004-838628386109",                        [{"hovertemplate":"Year=%{x}<br>Weight (kg)=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2022,2022,2022,2022,2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003],"xaxis":"x","y":[7540.24,null,443.0,90.0,9425.21,4027.115,3036.587,3259.932,2703.926,1597.0,1748.0,1607.0,8093.0,3094.0,3725.0,null,
# ...

# %%
figIndiaImp
# Out:
# <div>                            <div id="aca25db8-af11-439c-b4b6-60258a26e433" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aca25db8-af11-439c-b4b6-60258a26e433")) {                    Plotly.newPlot(                        "aca25db8-af11-439c-b4b6-60258a26e433",                        [{"hovertemplate":"Year=%{x}<br>Weight (kg)=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2022,2022,2022,2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003],"xaxis":"x","y":[591.059,null,17001.201,464.217,651.477,395.708,393.529,460.693,391.0,322.0,19570.0,679.0,130.0,156.0,52.0,2640.0,535.0,3
# ...

# %%
indiaImportData
# Out:
#      Country or Area  Year                                          Commodity  \
# 1042           India  2022  Heterocyclic compounds; containing an unfused ...
# 1044           India  2022  Heterocyclic compounds; containing an unfused ...
# 1047           India  2022  Heterocyclic compounds; other fentanyls n.e.c....
# 1048           India  2021  Heterocyclic compounds; containing an unfused ...
# 1050           India  2020  Heterocyclic compounds; containing an unfused ...
# 1052           India  2019  Heterocyclic compounds; containing an unfused ...
# 1055           India  2018  Heterocyclic compounds; containing an unfused ...
# 1056           India  2017  Heterocyclic compounds; containing an unfused ...
# 1059           India  2016  Heterocyclic compounds; containing an unfused ...
# 1061           India  2015  Heterocyclic compounds; containing an unfused ...
# 1063           India  2014  Heterocyclic compounds; containing an unfused ...
# ...
